# %%
#intalando versão exata do Scikit-learn

# !pip install -q scikit-learn==1.2.1
# Out:
# [notice] A new release of pip available: 22.2.2 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '1.0.2'

# %%
#importando data set load iris do sklearn
from sklearn.datasets import load_iris
data = load_iris()

# %%
#carregando o dataset iris como dataframe do pandas
import pandas as pd 
df = pd.DataFrame(data['data'], columns = data['feature_names'])
df['species'] = data['target']
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
#grafico com duas variaveis 
df.plot.scatter(x='sepal length (cm)', y='sepal width (cm)')
# Out:
# <AxesSubplot:xlabel='sepal length (cm)', ylabel='sepal width (cm)'>

# %%
#grafico de area

columns= ['sepal length (cm)', 'petal length (cm)', 'petal width (cm)', 'sepal width (cm)']
df[columns].plot.area()
# Out:
# <AxesSubplot:>
